# %%
import napari_workflows
from napari_workflows._io_yaml_v1 import load_workflow
import napari
import napari_pyclesperanto_assistant
from napari_pyclesperanto_assistant._workflow_io_utility import *
from skimage.io import imread

filename = 'test_workflow_long.yaml'
workflow = load_workflow(filename)
print(workflow)
# Out:
# Workflow:
# Result of Black top-hat (scipy, nsbatwm) <- (<function black_tophat at 0x0000026C94202950>, 'Result of Percentile (scipy, nsbatwm)', 16.0)
# Result of Gaussian (scikit-image, nsbatwm) <- (<function gaussian_blur at 0x0000026C942023B0>, 'blobs', 4.0)
# Result of Gaussian (scikit-image, nsbatwm) [1] <- (<function gaussian_blur at 0x0000026C942023B0>, 'blobs_messed_up', 8.0)
# Result of Minimum (scipy, nsbatwm) <- (<function minimum_filter at 0x0000026C94202A70>, 'Result of Gaussian (scikit-image, nsbatwm)', 3.0)
# Result of Multiply images (numpy, nsbatwm) <- (<function multiply_images at 0x0000026C942039A0>, 'Result of Black top-hat (scipy, nsbatwm)', 'Result of Minimum (scipy, nsbatwm)')
# Result of Percentile (scipy, nsbatwm) <- (<function percentile_filter at 0x0000026C94202710>, 'Result of Gaussian (scikit-image, nsbatwm) [1]', 7.0, 9.0)
# Result of Remove labeled objects at the image border (scikit-image, nsbatwm) <- (<function remove_labels_on_edges at 0x0000026C94203130>, 'Result of Seeded watershed using local minima as seeds (nsbatwm)')
# Result of Seeded watershed using local minima as seeds (nsbatwm) <- (<function local_minima_seeded_watershed at 0x0000026C94203640>, 'Result of Multiply images (numpy, nsbatwm)', 9.0, 8.0)

# %%
desktop = 'C:/Users/ryans/Desktop/'
#desktop = 'C:/Users/ryans/Onedrive/Desktop/'

image1 = imread(desktop + 'blobs.tif')
image2 = imread(desktop + 'blobs_messed_up.tiff')

viewer = napari.Viewer()
viewer.add_image(image1)
viewer.add_image(image2)
# Out:
# C:\Users\ryans\anaconda3\envs\np_workflows_v1\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Image layer 'image2' at 0x26c93e23970>

# %%
initialise_root_functions(workflow=workflow, 
                          viewer=viewer)

# %%
root_functions = wf_steps_with_root_as_input(workflow)
layers = viewer.layers

followers = []
for root in root_functions:
    followers += workflow.followers_of(root)

for i,follower in enumerate(followers):
    layer_names = [str(lay) for lay in layers]
    sources = workflow.sources_of(follower)

    # checking if we have all input images to the function in the napari layers
    sources_present = True
    for source in sources:
        if source not in layer_names:
            sources_present = False

    # if some input images are missing we will process other images first
    if not sources_present:
        if follower not in followers[i+1:]:
            followers.append(follower)

    # if all input images are there we can continue
    else:
        func = workflow._tasks[follower][0]
        signat = signature_w_kwargs_from_function(workflow=workflow,
                                                  wf_step_name=follower)
        func.__signature__ = signat

        if len(sources) > 1:
            widget = make_flexible_gui(func, 
                                       viewer, 
                                       follower,
                                       autocall= False)
        else:
            widget = make_flexible_gui(func, 
                                       viewer, 
                                       follower)

        viewer.window.add_dock_widget(widget, name= follower[10:])
        set_choices(workflow= workflow,
                    wf_step= follower,
                    viewer= viewer,
                    widget= widget)
        widget()

        new_followers = workflow.followers_of(follower)
        for new_follower in new_followers:
            if new_follower not in followers[i+1:]:
                followers += new_followers
                break
# Out:
# followers looks like ['Result of Minimum (scipy, nsbatwm)', 'Result of Percentile (scipy, nsbatwm)']
#
# iteration number0, current follower Result of Minimum (scipy, nsbatwm)
#
# new foller is ['Result of Multiply images (numpy, nsbatwm)']
#
# followers[i+1:] looks like ['Result of Percentile (scipy, nsbatwm)']
# new follower appended
#
# followers looks like ['Result of Minimum (scipy, nsbatwm)', 'Result of Percentile (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)']
#
# iteration number1, current follower Result of Percentile (scipy, nsbatwm)
#
# new foller is ['Result of Black top-hat (scipy, nsbatwm)']
#
# followers[i+1:] looks like ['Result of Multiply images (numpy, nsbatwm)']
# new follower appended
#
# followers looks like ['Result of Minimum (scipy, nsbatwm)', 'Result of Percentile (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)', 'Result of Black top-hat (scipy, nsbatwm)']
#
# iteration number2, current follower Result of Multiply images (numpy, nsbatwm)
#
# we are here because of Result of Multiply images (numpy, nsbatwm) and the sources ['Result of Black top-hat (scipy, nsbatwm)', 'Result of Minimum (scipy, nsbatwm)']
#
# appended Result of Multiply images (numpy, nsbatwm) because ['Result of Black top-hat (scipy, nsbatwm)', 'Result of Minimum (scipy, nsbatwm)'] includes non existing layer
#
# iteration number3, current follower Result of Black top-hat (scipy, nsbatwm)
#
# new foller is ['Result of Multiply images (numpy, nsbatwm)']
#
# followers[i+1:] looks like ['Result of Multiply images (numpy, nsbatwm)']
# followers looks like ['Result of Minimum (scipy, nsbatwm)', 'Result of Percentile (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)', 'Result of Black top-hat (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)']
#
# iteration number4, current follower Result of Multiply images (numpy, nsbatwm)
#
# new foller is ['Result of Seeded watershed using local minima as seeds (nsbatwm)']
#
# followers[i+1:] looks like []
# new follower appended
#
# followers looks like ['Result of Minimum (scipy, nsbatwm)', 'Result of Percentile (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)', 'Result of Black top-hat (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)', 'Result of Seeded watershed using local minima as seeds (nsbatwm)']
#
# iteration number5, current follower Result of Seeded watershed using local minima as seeds (nsbatwm)
#
# new foller is ['Result of Remove labeled objects at the image border (scikit-image, nsbatwm)']
#
# followers[i+1:] looks like []
# new follower appended
#
# followers looks like ['Result of Minimum (scipy, nsbatwm)', 'Result of Percentile (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)', 'Result of Black top-hat (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)', 'Result of Seeded watershed using local minima as seeds (nsbatwm)', 'Result of Remove labeled objects at the image border (scikit-image, nsbatwm)']
#
# iteration number6, current follower Result of Remove labeled objects at the image border (scikit-image, nsbatwm)
#
# new foller is []
#
# followers[i+1:] looks like []
# followers looks like ['Result of Minimum (scipy, nsbatwm)', 'Result of Percentile (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)', 'Result of Black top-hat (scipy, nsbatwm)', 'Result of Multiply images (numpy, nsbatwm)', 'Result of Seeded watershed using local minima as seeds (nsbatwm)', 'Result of Remove labeled objects at the image border (scikit-image, nsbatwm)']
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject::connect: Cannot queue arguments of type 'QVector<int>'
# (Make sure 'QVector<int>' is registered using qRegisterMetaType().)
# WARNING: QObject: Cannot create children for a parent that is in a different thread.
# (Parent is QtLabelsControls(0x26c9ca65f00), parent's thread is QThread(0x26cec98c020), current thread is QThreadPoolThread(0x26cecb5ab80)
# WARNING: QObject: Cannot create children for a parent that is in a different thread.
# (Parent is QtLabelsControls(0x26c9ca65f00), parent's thread is QThread(0x26cec98c020), current thread is QThreadPoolThread(0x26cecb5ab80)
# WARNING: QObject: Cannot create children for a parent that is in a different thread.
# (Parent is QtLabelsControls(0x26c9ca65f00), parent's thread is QThread(0x26cec98c020), current thread is QThreadPoolThread(0x26cecb5ab80)
# WARNING: QObject: Cannot create children for a parent that is in a different thread.
# (Parent is QtLabelsControls(0x26c9ca65f00), parent's thread is QThread(0x26cec98c020), current thread is QThreadPoolThread(0x26cecb5ab80)
