# %%
import napari_workflows
from napari_workflows._io_yaml_v1 import load_workflow
import napari
import napari_pyclesperanto_assistant
from napari_pyclesperanto_assistant._workflow_io_utility import *
from skimage.io import imread
import numpy as np

filename = 'test_workflow_multiple_nodes_multiply.yaml'
workflow = load_workflow(filename)
print(workflow)
# Out:
# Workflow:
# Result of Black top-hat (scipy, nsbatwm) <- (<function black_tophat at 0x0000022CC3A0D280>, 'Result of Gaussian (scikit-image, nsbatwm) [1]', 19.0)
# Result of Gaussian (scikit-image, nsbatwm) <- (<function gaussian_blur at 0x0000022CC3A09CA0>, 'blobs', 6.0)
# Result of Gaussian (scikit-image, nsbatwm) [1] <- (<function gaussian_blur at 0x0000022CC3A09CA0>, 'blobs_messed_up', 4.0)
# Result of Multiply images (numpy, nsbatwm) <- (<function multiply_images at 0x0000022CC3A60310>, 'Result of Black top-hat (scipy, nsbatwm)', 'Result of Gaussian (scikit-image, nsbatwm)')

# %%
#desktop = 'C:/Users/ryans/Desktop/'
desktop = 'C:/Users/ryans/Onedrive/Desktop/'
image1 = imread(desktop + 'blobs.tif')
image2 = imread(desktop + 'blobs_messed_up.tiff')

viewer = napari.Viewer()
viewer.add_image(image1)
viewer.add_image(image2)
# Out:
# C:\Users\ryans\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Image layer 'image2' at 0x22ccccec2b0>

# %%
initialise_root_functions(workflow=workflow, 
                          viewer=viewer)

# %%
func = workflow._tasks['Result of Gaussian (scikit-image, nsbatwm)'][0]
        
signat = signature_w_kwargs_from_function(workflow=workflow,
                                          wf_step_name='Result of Gaussian (scikit-image, nsbatwm)')

signat
# Out:
# <Signature (image: <function NewType.<locals>.new_type at 0x0000022CB23D9D30>, *, sigma: float = 6.0, viewer: napari.viewer.Viewer = None) -> <function NewType.<locals>.new_type at 0x0000022CB23D9D30>>

# %%
workflow.sources_of('Result of Gaussian (scikit-image, nsbatwm)')
# Out:
# ['blobs']

# %%
wf_step_name = 'Result of Gaussian (scikit-image, nsbatwm)'
func     = workflow._tasks[wf_step_name][0]
arg_vals = workflow._tasks[wf_step_name][1:] 
# getting the keywords corresponding to the values
keyword_list = list(signature(func).parameters.keys())

# creating the kwargs dict
kw_dict = {}
for kw, val in zip(keyword_list, arg_vals):
    kw_dict[kw] = val

kw_dict
# Out:
# {'image': 'blobs', 'sigma': 6.0}

# %%
dict_keys = list(kw_dict.keys())
dict_keys
# Out:
# ['image', 'sigma']

# %%
input_image_names = workflow.sources_of(wf_step_name)

for name in dict_keys:
    if ((kw_dict[name] in input_image_names) and (name != 'viewer')):
        kw_dict.pop(name) # we are making an assumption that the input will aways be this
        
kw_dict
# Out:
# {'sigma': 6.0}

# %%
input_image_names
# Out:
# ['blobs']

# %%
keyword_list
# Out:
# ['image', 'sigma', 'viewer']

# %%
load_remaining_workflow(workflow=workflow,
                        viewer=viewer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py in _on_value_change(self, value)
#      55         if value is self.null_value and not self._nullable:
#      56             return
# ---> 57         self.changed.emit(value)
#      58
#      59     def get_value(self):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      83                     # TODO: add better exception handling
#      84                     if self._new_callback.get(slot):
# ---> 85                         cb(*args[:max_args])
#      86                     else:
#      87                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py in <lambda>()
#     163         """Insert widget at ``key``."""
#     164         if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165             widget.changed.connect(lambda: self.changed.emit(self))
#     166         _widget = widget
#     167
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      83                     # TODO: add better exception handling
#      84                     if self._new_callback.get(slot):
# ---> 85                         cb(*args[:max_args])
#      86                     else:
#      87                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in _on_change(self)
#     219             self._dump()
#     220         if self._auto_call:
# --> 221             self()
#     222
#     223     @property
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     301         self._tqdm_depth = 0  # reset the tqdm stack count
#     302         with _function_name_pointing_to_widget(self):
# --> 303             value = self._function(*bound.args, **bound.kwargs)
#     304
#     305         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari_pyclesperanto_assistant_fork\napari_pyclesperanto_assistant\_workflow_io_utility.py in worker_func(*iargs, **ikwargs)
#     127     @wraps(func)
#     128     def worker_func(*iargs, **ikwargs):
# --> 129         data = func(*iargs, **ikwargs)
#     130         if data is None:
#     131             return None
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_time_slicer\__init__.py in worker_function(*args, **kwargs)
#      47
#      48         # call the decorated function
# ---> 49         result = function(*bound.args, **bound.kwargs)
#      50         return result
#      51
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_segment_blobs_and_things_with_membranes\__init__.py in black_tophat(image, radius, viewer)
#     213 @time_slicer
#     214 def black_tophat(image: napari.types.ImageData, radius: float = 2, viewer: napari.Viewer = None) -> napari.types.ImageData:
# --> 215     return scipy.ndimage.black_tophat(image.astype(float), size=radius * 2 + 1)
#     216
#     217
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in black_tophat(input, size, footprint, structure, output, mode, cval, origin)
#    1838     if (size is not None) and (footprint is not None):
#    1839         warnings.warn("ignoring size because footprint is set", UserWarning, stacklevel=2)
# -> 1840     tmp = grey_dilation(input, size, footprint, structure, None, mode,
#    1841                         cval, origin)
#    1842     tmp = grey_erosion(tmp, size, footprint, structure, output, mode,
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in grey_dilation(input, size, footprint, structure, output, mode, cval, origin)
#    1364         else:
#    1365             sz = size[ii]
# -> 1366         if not sz & 1:
#    1367             origin[ii] -= 1
#    1368
#
# TypeError: unsupported operand type(s) for &: 'float' and 'int'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py in _on_value_change(self, value)
#      55         if value is self.null_value and not self._nullable:
#      56             return
# ---> 57         self.changed.emit(value)
#      58
#      59     def get_value(self):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      83                     # TODO: add better exception handling
#      84                     if self._new_callback.get(slot):
# ---> 85                         cb(*args[:max_args])
#      86                     else:
#      87                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py in <lambda>()
#     163         """Insert widget at ``key``."""
#     164         if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165             widget.changed.connect(lambda: self.changed.emit(self))
#     166         _widget = widget
#     167
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      83                     # TODO: add better exception handling
#      84                     if self._new_callback.get(slot):
# ---> 85                         cb(*args[:max_args])
#      86                     else:
#      87                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in _on_change(self)
#     219             self._dump()
#     220         if self._auto_call:
# --> 221             self()
#     222
#     223     @property
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     301         self._tqdm_depth = 0  # reset the tqdm stack count
#     302         with _function_name_pointing_to_widget(self):
# --> 303             value = self._function(*bound.args, **bound.kwargs)
#     304
#     305         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari_pyclesperanto_assistant_fork\napari_pyclesperanto_assistant\_workflow_io_utility.py in worker_func(*iargs, **ikwargs)
#     127     @wraps(func)
#     128     def worker_func(*iargs, **ikwargs):
# --> 129         data = func(*iargs, **ikwargs)
#     130         if data is None:
#     131             return None
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_time_slicer\__init__.py in worker_function(*args, **kwargs)
#      47
#      48         # call the decorated function
# ---> 49         result = function(*bound.args, **bound.kwargs)
#      50         return result
#      51
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_segment_blobs_and_things_with_membranes\__init__.py in black_tophat(image, radius, viewer)
#     213 @time_slicer
#     214 def black_tophat(image: napari.types.ImageData, radius: float = 2, viewer: napari.Viewer = None) -> napari.types.ImageData:
# --> 215     return scipy.ndimage.black_tophat(image.astype(float), size=radius * 2 + 1)
#     216
#     217
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in black_tophat(input, size, footprint, structure, output, mode, cval, origin)
#    1838     if (size is not None) and (footprint is not None):
#    1839         warnings.warn("ignoring size because footprint is set", UserWarning, stacklevel=2)
# -> 1840     tmp = grey_dilation(input, size, footprint, structure, None, mode,
#    1841                         cval, origin)
#    1842     tmp = grey_erosion(tmp, size, footprint, structure, output, mode,
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in grey_dilation(input, size, footprint, structure, output, mode, cval, origin)
#    1364         else:
#    1365             sz = size[ii]
# -> 1366         if not sz & 1:
#    1367             origin[ii] -= 1
#    1368
#
# TypeError: unsupported operand type(s) for &: 'float' and 'int'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py in _on_value_change(self, value)
#      55         if value is self.null_value and not self._nullable:
#      56             return
# ---> 57         self.changed.emit(value)
#      58
#      59     def get_value(self):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      83                     # TODO: add better exception handling
#      84                     if self._new_callback.get(slot):
# ---> 85                         cb(*args[:max_args])
#      86                     else:
#      87                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py in <lambda>()
#     163         """Insert widget at ``key``."""
#     164         if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165             widget.changed.connect(lambda: self.changed.emit(self))
#     166         _widget = widget
#     167
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      83                     # TODO: add better exception handling
#      84                     if self._new_callback.get(slot):
# ---> 85                         cb(*args[:max_args])
#      86                     else:
#      87                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in _on_change(self)
#     219             self._dump()
#     220         if self._auto_call:
# --> 221             self()
#     222
#     223     @property
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     301         self._tqdm_depth = 0  # reset the tqdm stack count
#     302         with _function_name_pointing_to_widget(self):
# --> 303             value = self._function(*bound.args, **bound.kwargs)
#     304
#     305         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari_pyclesperanto_assistant_fork\napari_pyclesperanto_assistant\_workflow_io_utility.py in worker_func(*iargs, **ikwargs)
#     127     @wraps(func)
#     128     def worker_func(*iargs, **ikwargs):
# --> 129         data = func(*iargs, **ikwargs)
#     130         if data is None:
#     131             return None
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_time_slicer\__init__.py in worker_function(*args, **kwargs)
#      47
#      48         # call the decorated function
# ---> 49         result = function(*bound.args, **bound.kwargs)
#      50         return result
#      51
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_segment_blobs_and_things_with_membranes\__init__.py in black_tophat(image, radius, viewer)
#     213 @time_slicer
#     214 def black_tophat(image: napari.types.ImageData, radius: float = 2, viewer: napari.Viewer = None) -> napari.types.ImageData:
# --> 215     return scipy.ndimage.black_tophat(image.astype(float), size=radius * 2 + 1)
#     216
#     217
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in black_tophat(input, size, footprint, structure, output, mode, cval, origin)
#    1838     if (size is not None) and (footprint is not None):
#    1839         warnings.warn("ignoring size because footprint is set", UserWarning, stacklevel=2)
# -> 1840     tmp = grey_dilation(input, size, footprint, structure, None, mode,
#    1841                         cval, origin)
#    1842     tmp = grey_erosion(tmp, size, footprint, structure, output, mode,
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in grey_dilation(input, size, footprint, structure, output, mode, cval, origin)
#    1364         else:
#    1365             sz = size[ii]
# -> 1366         if not sz & 1:
#    1367             origin[ii] -= 1
#    1368
#
# TypeError: unsupported operand type(s) for &: 'float' and 'int'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py in _on_value_change(self, value)
#      55         if value is self.null_value and not self._nullable:
#      56             return
# ---> 57         self.changed.emit(value)
#      58
#      59     def get_value(self):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      83                     # TODO: add better exception handling
#      84                     if self._new_callback.get(slot):
# ---> 85                         cb(*args[:max_args])
#      86                     else:
#      87                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py in <lambda>()
#     163         """Insert widget at ``key``."""
#     164         if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165             widget.changed.connect(lambda: self.changed.emit(self))
#     166         _widget = widget
#     167
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      83                     # TODO: add better exception handling
#      84                     if self._new_callback.get(slot):
# ---> 85                         cb(*args[:max_args])
#      86                     else:
#      87                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in _on_change(self)
#     219             self._dump()
#     220         if self._auto_call:
# --> 221             self()
#     222
#     223     @property
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     301         self._tqdm_depth = 0  # reset the tqdm stack count
#     302         with _function_name_pointing_to_widget(self):
# --> 303             value = self._function(*bound.args, **bound.kwargs)
#     304
#     305         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari_pyclesperanto_assistant_fork\napari_pyclesperanto_assistant\_workflow_io_utility.py in worker_func(*iargs, **ikwargs)
#     127     @wraps(func)
#     128     def worker_func(*iargs, **ikwargs):
# --> 129         data = func(*iargs, **ikwargs)
#     130         if data is None:
#     131             return None
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_time_slicer\__init__.py in worker_function(*args, **kwargs)
#      47
#      48         # call the decorated function
# ---> 49         result = function(*bound.args, **bound.kwargs)
#      50         return result
#      51
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_segment_blobs_and_things_with_membranes\__init__.py in black_tophat(image, radius, viewer)
#     213 @time_slicer
#     214 def black_tophat(image: napari.types.ImageData, radius: float = 2, viewer: napari.Viewer = None) -> napari.types.ImageData:
# --> 215     return scipy.ndimage.black_tophat(image.astype(float), size=radius * 2 + 1)
#     216
#     217
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in black_tophat(input, size, footprint, structure, output, mode, cval, origin)
#    1838     if (size is not None) and (footprint is not None):
#    1839         warnings.warn("ignoring size because footprint is set", UserWarning, stacklevel=2)
# -> 1840     tmp = grey_dilation(input, size, footprint, structure, None, mode,
#    1841                         cval, origin)
#    1842     tmp = grey_erosion(tmp, size, footprint, structure, output, mode,
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in grey_dilation(input, size, footprint, structure, output, mode, cval, origin)
#    1364         else:
#    1365             sz = size[ii]
# -> 1366         if not sz & 1:
#    1367             origin[ii] -= 1
#    1368
#
# TypeError: unsupported operand type(s) for &: 'float' and 'int'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18068/1989791416.py in <module>
# ----> 1 load_remaining_workflow(workflow=workflow,
#       2                         viewer=viewer)
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari_pyclesperanto_assistant_fork\napari_pyclesperanto_assistant\_workflow_io_utility.py in load_remaining_workflow(workflow, viewer)
#      97                         widget= widget)
#      98
# ---> 99             widget()
#     100
#     101             new_follower = workflow.followers_of(follower)
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     301         self._tqdm_depth = 0  # reset the tqdm stack count
#     302         with _function_name_pointing_to_widget(self):
# --> 303             value = self._function(*bound.args, **bound.kwargs)
#     304
#     305         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari_pyclesperanto_assistant_fork\napari_pyclesperanto_assistant\_workflow_io_utility.py in worker_func(*iargs, **ikwargs)
#     127     @wraps(func)
#     128     def worker_func(*iargs, **ikwargs):
# --> 129         data = func(*iargs, **ikwargs)
#     130         if data is None:
#     131             return None
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_time_slicer\__init__.py in worker_function(*args, **kwargs)
#      47
#      48         # call the decorated function
# ---> 49         result = function(*bound.args, **bound.kwargs)
#      50         return result
#      51
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_segment_blobs_and_things_with_membranes\__init__.py in black_tophat(image, radius, viewer)
#     213 @time_slicer
#     214 def black_tophat(image: napari.types.ImageData, radius: float = 2, viewer: napari.Viewer = None) -> napari.types.ImageData:
# --> 215     return scipy.ndimage.black_tophat(image.astype(float), size=radius * 2 + 1)
#     216
#     217
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in black_tophat(input, size, footprint, structure, output, mode, cval, origin)
#    1838     if (size is not None) and (footprint is not None):
#    1839         warnings.warn("ignoring size because footprint is set", UserWarning, stacklevel=2)
# -> 1840     tmp = grey_dilation(input, size, footprint, structure, None, mode,
#    1841                         cval, origin)
#    1842     tmp = grey_erosion(tmp, size, footprint, structure, output, mode,
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\scipy\ndimage\morphology.py in grey_dilation(input, size, footprint, structure, output, mode, cval, origin)
#    1364         else:
#    1365             sz = size[ii]
# -> 1366         if not sz & 1:
#    1367             origin[ii] -= 1
#    1368
#
# TypeError: unsupported operand type(s) for &: 'float' and 'int'
